# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(pd.read_csv('scraped_and_full_data.csv'))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'companyId', 'jobId', 'country', 'stateProvince',
#        'city', 'avgOverallRating', 'numReviews', 'industry', 'normTitle',
#        'normTitleCategory', 'descriptionCharacterLength',
#        'descriptionWordCount', 'experienceRequired', 'estimatedSalary',
#        'salaryCurrency', 'jobLanguage', 'supervisingJob', 'licenseRequiredJob',
#        'educationRequirements', 'jobAgeDays', 'clicks', 'localClicks', 'State',
#        'Number of Residents in Millions', '2017rate', 'Index', 'Grocery',
#        'Housing', 'Utilities', 'Transportation', 'Heath', 'Misc.'],
#       dtype='object')

# %% [markdown]
# Get rid of unneeded columns, and drop NA values.

# %%
unneeded = ['Unnamed: 0', 'date', 'companyId', 'country', 'avgOverallRating', 'numReviews', 'descriptionCharacterLength',
       'descriptionWordCount', 'experienceRequired','salaryCurrency', 'jobLanguage', 'supervisingJob', 'licenseRequiredJob',
       'jobAgeDays', 'Index', 'Grocery', "industry", "city", "estimatedSalary"
       'Housing', 'Utilities', 'Transportation', 'Heath', 'Misc.', 'normTitle',
       'normTitleCategory']

# %%
df_important = df.drop([col for col in unneeded if col in df], axis = 1)
df_important.head()
# Out:
#         jobId stateProvince  estimatedSalary educationRequirements  clicks  \
# 0  job0000002            AZ            22800           High School      12
# 1  job0000416            AZ            27000                  None      24
# 2  job0000420            AZ            43700                  None      20
# 3  job0000420            AZ            43700                  None      12
# 4  job0000420            AZ            43700                  None      17
#
#    localClicks    State  Number of Residents in Millions  2017rate  Housing
# 0            2  Arizona                             7.02       4.9     89.5
# 1            2  Arizona                             7.02       4.9     89.5
# 2            2  Arizona                             7.02       4.9     89.5
# 3            1  Arizona                             7.02       4.9     89.5
# 4            1  Arizona                             7.02       4.9     89.5

# %%
df_important = df_important.dropna(subset=["educationRequirements"])
df_important.head()
# Out:
#         jobId stateProvince  estimatedSalary educationRequirements  clicks  \
# 0  job0000002            AZ            22800           High School      12
# 1  job0000416            AZ            27000                  None      24
# 2  job0000420            AZ            43700                  None      20
# 3  job0000420            AZ            43700                  None      12
# 4  job0000420            AZ            43700                  None      17
#
#    localClicks    State  Number of Residents in Millions  2017rate  Housing
# 0            2  Arizona                             7.02       4.9     89.5
# 1            2  Arizona                             7.02       4.9     89.5
# 2            2  Arizona                             7.02       4.9     89.5
# 3            1  Arizona                             7.02       4.9     89.5
# 4            1  Arizona                             7.02       4.9     89.5

# %% [markdown]
# Here we will create a new dataframe with columns based on calculations from the data from the total clicks dataframe.

# %%
df_total_clicks = pd.DataFrame(None)
df_total_clicks["Total Job Clicks"] = df_important.groupby(["jobId"])["clicks"].sum()
df_total_clicks["Total Job Local Clicks"] = df_important.groupby(["jobId"])["localClicks"].sum()

# %%
df_total_clicks = df_total_clicks.reset_index()
df_total_clicks["localClicks/totalClicks"] = df_total_clicks["Total Job Local Clicks"]/df_total_clicks["Total Job Clicks"]
# Out:
#         jobId  Total Job Clicks  Total Job Local Clicks  \
# 0  job0000002                12                       2
# 1  job0000003                15                       3
# 2  job0000005                25                       8
# 3  job0000006                33                       1
# 4  job0000008                87                       9
#
#    localClicks/totalClicks
# 0                 0.166667
# 1                 0.200000
# 2                 0.320000
# 3                 0.030303
# 4                 0.103448

# %%
unemployment = pd.DataFrame(df_important.groupby(["stateProvince"])["2017rate"].mean()).reset_index()
unemployment.head()
# Out:
#    stateProvince  2017rate
# 0             AK       7.2
# 1             AL       4.4
# 2             AR       3.7
# 3             AZ       4.9
# 4             CA       4.8
# 5             CO       2.8
# 6             CT       4.7
# 7             DE       4.6
# 8             FL       4.2
# 9             GA       4.7
# 10            HI       2.4
# 11            IA       3.1
# 12            ID       3.2
# 13            IL       5.0
# 14            IN       3.5
# 15            KS       3.6
# 16            KY       4.9
# 17            LA       5.1
# 18            MA       3.7
# 19            MD       4.1
# 20            ME       3.3
# 21            MI       4.6
# 22            MN       3.5
# 23            MO       3.8
# 24            MS       5.1
# 25            MT       4.0
# 26            NC       4.6
# 27            ND       2.6
# 28            NE       2.9
# 29            NH       2.7
# 30            NJ       4.6
# 31            NM       6.2
# 32            NV       5.0
# 33            NY       4.7
# 34            OH       5.0
# 35            OK       4.3
# 36            OR       4.1
# 37            PA       4.9
# 38            RI       4.5
# 39            SC       4.3
# 40            SD       3.3
# 41            TN       3.7
# 42            TX       4.3
# 43            UT       3.2
# 44            VA       3.8
# 45            VT       3.0
# 46            WA       4.8
# 47            WI       3.3
# 48            WV       5.2
# 49            WY       4.2

# %% [markdown]
# We will then create dataframes for the educational requirements of job types in every state, as well as the attention given to different jobs in each state scaled by state unemployment.

# %%
job_state = pd.DataFrame(None)
job_state["Ones"] = df_important.groupby(["jobId"])["stateProvince"].value_counts()
job_state = job_state.reset_index()
job_state = job_state.drop(['Ones'], axis = 1)

# %%
edu = pd.DataFrame(None)
edu["Ones"] = df_important.groupby(["jobId"])["educationRequirements"].value_counts()
edu = edu.reset_index()
edu = edu.drop(["Ones"], axis = 1)

# %%
merge1 = job_state.merge(unemployment)
merge2 = merge1.merge(edu)
df_individual_jobs = merge2.merge(df_total_clicks)

# %%
df_edu_clicks_by_state = pd.DataFrame(None)
df_edu_clicks_by_state["Average Local:Total Click Ratio"] = df_individual_jobs.groupby(["stateProvince", "educationRequirements"])["localClicks/totalClicks"].mean()
df_edu_clicks_by_state = df_edu_clicks_by_state.reset_index()
df_edu_clicks_by_state = df_edu_clicks_by_state.merge(unemployment)
df_edu_clicks_by_state["Average Local:Total Click Ratio/State Unemployment"] = df_edu_clicks_by_state["Average Local:Total Click Ratio"]/df_edu_clicks_by_state["2017rate"]
df_edu_clicks_by_state
# Out:
#     stateProvince educationRequirements  Average Local:Total Click Ratio  \
# 0              AK           High School                         0.184546
# 1              AK      Higher Education                         0.176235
# 2              AK                  None                         0.184500
# 3              AL           High School                         0.170290
# 4              AL      Higher Education                         0.165083
# 5              AL                  None                         0.170260
# 6              AR           High School                         0.163654
# 7              AR      Higher Education                         0.143603
# 8              AR                  None                         0.160872
# 9              AZ           High School                         0.193026
# 10             AZ      Higher Education                         0.173912
# 11             AZ                  None                         0.187839
# 12             CA           High School                         0.154276
# 13             CA      Higher Education                         0.128008
# 14             CA                  None                         0.154328
# 15             CO           High School                         0.185892
# 16             CO      Higher Education                         0.161167
# 17             CO                  None                         0.175507
# 18             CT           High School                         0.116987
# 19             CT      Higher Education                         0.092597
# 20             CT                  None                         0.118755
# 21             DE           High School                         0.145312
# 22             DE      Higher Education                         0.121125
# 23             DE                  None                         0.156101
# 24             FL           High School                         0.198677
# 25             FL      Higher Education                         0.165098
# 26             FL                  None                         0.184995
# 27             GA           High School                         0.157469
# 28             GA      Higher Education                         0.144864
# 29             GA                  None                         0.161769
# ..            ...                   ...                              ...
# 120            SD           High School                         0.252207
# 121            SD      Higher Education                         0.233607
# 122            SD                  None                         0.205553
# 123            TN           High School                         0.176538
# 124            TN      Higher Education                         0.170018
# 125            TN                  None                         0.180800
# 126            TX           High School                         0.220308
# 127            TX      Higher Education                         0.192987
# 128            TX                  None                         0.203259
# 129            UT           High School                         0.161151
# 130            UT      Higher Education                         0.152757
# 131            UT                  None                         0.159112
# 132            VA           High School                         0.163794
# 133            VA      Higher Education                         0.115454
# 134            VA                  None                         0.160909
# 135            VT           High School                         0.117180
# 136            VT      Higher Education                         0.101123
# 137            VT                  None                         0.110000
# 138            WA           High School                         0.173668
# 139            WA      Higher Education                         0.151610
# 140            WA                  None                         0.163370
# 141            WI           High School                         0.173884
# 142            WI      Higher Education                         0.158130
# 143            WI                  None                         0.167569
# 144            WV           High School                         0.148450
# 145            WV      Higher Education                         0.153002
# 146            WV                  None                         0.148708
# 147            WY           High School                         0.294241
# 148            WY      Higher Education                         0.211322
# 149            WY                  None                         0.197395
#
#      2017rate  Average Local:Total Click Ratio/State Unemployment
# 0         7.2                                           0.025631
# 1         7.2                                           0.024477
# 2         7.2                                           0.025625
# 3         4.4                                           0.038702
# 4         4.4                                           0.037519
# 5         4.4                                           0.038695
# 6         3.7                                           0.044231
# 7         3.7                                           0.038812
# 8         3.7                                           0.043479
# 9         4.9                                           0.039393
# 10        4.9                                           0.035492
# 11        4.9                                           0.038334
# 12        4.8                                           0.032141
# 13        4.8                                           0.026668
# 14        4.8                                           0.032152
# 15        2.8                                           0.066390
# 16        2.8                                           0.057560
# 17        2.8                                           0.062681
# 18        4.7                                           0.024891
# 19        4.7                                           0.019701
# 20        4.7                                           0.025267
# 21        4.6                                           0.031589
# 22        4.6                                           0.026331
# 23        4.6                                           0.033935
# 24        4.2                                           0.047304
# 25        4.2                                           0.039309
# 26        4.2                                           0.044046
# 27        4.7                                           0.033504
# 28        4.7                                           0.030822
# 29        4.7                                           0.034419
# ..        ...                                                ...
# 120       3.3                                           0.076426
# 121       3.3                                           0.070790
# 122       3.3                                           0.062289
# 123       3.7                                           0.047713
# 124       3.7                                           0.045951
# 125       3.7                                           0.048865
# 126       4.3                                           0.051235
# 127       4.3                                           0.044881
# 128       4.3                                           0.047270
# 129       3.2                                           0.050360
# 130       3.2                                           0.047736
# 131       3.2                                           0.049722
# 132       3.8                                           0.043104
# 133       3.8                                           0.030383
# 134       3.8                                           0.042345
# 135       3.0                                           0.039060
# 136       3.0                                           0.033708
# 137       3.0                                           0.036667
# 138       4.8                                           0.036181
# 139       4.8                                           0.031585
# 140       4.8                                           0.034035
# 141       3.3                                           0.052692
# 142       3.3                                           0.047918
# 143       3.3                                           0.050778
# 144       5.2                                           0.028548
# 145       5.2                                           0.029424
# 146       5.2                                           0.028598
# 147       4.2                                           0.070057
# 148       4.2                                           0.050315
# 149       4.2                                           0.046999
#
# [150 rows x 5 columns]

# %%
df_edu_clicks_by_state.to_csv("edu_click_ratio_by_state.csv")
